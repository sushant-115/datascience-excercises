# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
#from keras.layers.normalization import BatchNormalization
from keras import backend
from keras.optimizers import Adam
from sklearn.metrics import r2_score
from mlxtend.plotting import plot_decision_regions

# %%
# !pip3 install keras
# Out:
# Requirement already satisfied: keras in /opt/homebrew/anaconda3/lib/python3.11/site-packages (3.3.3)
# Requirement already satisfied: absl-py in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from keras) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %% [markdown]
# ## __1 - Business Problem__
# ___Build a Neural Network model for 50_startups data to predict profit___

# %% [markdown]
# ## __2 - Data collection and description__

# %%
df = pd.read_csv("../Raw Data//50_Startups.csv")

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df1.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df1.describe().T
# Out:
#                  count         mean            std       min          25%  \
# R&D Spend         50.0   73721.6156   45902.256482      0.00   39936.3700
# Administration    50.0  121344.6396   28017.802755  51283.14  103730.8750
# Marketing Spend   50.0  211025.0978  122290.310726      0.00  129300.1325
# Profit            50.0  112012.6392   40306.180338  14681.40   90138.9025
#
#                         50%          75%        max
# R&D Spend         73051.080  101602.8000  165349.20
# Administration   122699.795  144842.1800  182645.56
# Marketing Spend  212716.240  299469.0850  471784.10
# Profit           107978.190  139765.9775  192261.83

# %% [markdown]
# ### Outlier Check

# %%
ax = sns.boxplot(df1['Profit'])

# %% [markdown]
# ### There are 1 Outlier instances in our data

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['Profit'].skew()))
print("Kurtosis: {}".format(df1['Profit'].kurtosis()))
ax = sns.kdeplot(df1['Profit'],shade=True,color='g')
plt.xticks([i for i in range(10000,200000,20000)])
plt.show()
# Out:
# Skew: 0.023291019769116614
# Kurtosis: -0.06385888546853113
# /var/folders/qf/59s2hyj17wx1jdx8qbwchk8w0000gn/T/ipykernel_63825/2883512899.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(df1['Profit'],shade=True,color='g')
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### The Data is positively skewed and has a negative kurtosis value
# ### Majority of the profit is in the range 70000 to 150000

# %%
dfa = df1[df1.columns]
month_colum = dfa.select_dtypes(include='object').columns.tolist()

# %%
plt.figure(figsize=(16,10))
for i,col in enumerate(month_colum,1):
    plt.subplot(2,2,i)
    sns.countplot(data=dfa,y=col)
    plt.subplot(2,2,i+2)
    df1[col].value_counts(normalize=True).plot.bar()
    plt.ylabel(col)
    plt.xlabel('% distribution per category')
plt.tight_layout()
plt.show()

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
# /var/folders/qf/59s2hyj17wx1jdx8qbwchk8w0000gn/T/ipykernel_63825/2239169671.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],color='g',shade=True)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/qf/59s2hyj17wx1jdx8qbwchk8w0000gn/T/ipykernel_63825/2239169671.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],color='g',shade=True)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/qf/59s2hyj17wx1jdx8qbwchk8w0000gn/T/ipykernel_63825/2239169671.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],color='g',shade=True)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/qf/59s2hyj17wx1jdx8qbwchk8w0000gn/T/ipykernel_63825/2239169671.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],color='g',shade=True)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
#           R&D Spend  Administration  Marketing Spend    Profit
# skewness   0.164002       -0.489025        -0.046472  0.023291
# kurtosis  -0.761465        0.225071        -0.671701 -0.063859

# %% [markdown]
# ### Finding Correlation

# %%
df1 = pd.get_dummies(df1, columns = ['State'])

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## __3 - Neural Network Model__

# %%
df1.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_California', 'State_Florida', 'State_New York'],
#       dtype='object')

# %%
def norm_func(i):
    x = (i - i.min())/(i.max()-i.min())
    return (x)

# %%
df1 = norm_func(df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df1 = norm_func(df1)
#
# Cell In[36], line 2, in norm_func(i)
#       1 def norm_func(i):
# ----> 2     x = (i - i.min())/(i.max()-i.min())
#       3     return (x)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:7644, in DataFrame._arith_method(self, other, op)
#    7641 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7643 with np.errstate(all="ignore"):
# -> 7644     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7645 return self._construct_result(new_data)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:7687, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7681     assert self.columns.equals(right.columns)
#    7682     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7683     #  fails in cases with empty columns reached via
#    7684     #  _frame_arith_method_with_reindex
#    7685
#    7686     # TODO operate_blockwise expects a manager of the same type
# -> 7687     bm = self._mgr.operate_blockwise(
#    7688         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7689         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7690         # "ArrayManager"
#    7691         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7692         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7693         # "BlockManager"
#    7694         right._mgr,  # type: ignore[arg-type]
#    7695         array_op,
#    7696     )
#    7697     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7699 elif isinstance(right, Series) and axis == 1:
#    7700     # axis=1 means we want to operate row-by-row
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1470, in BlockManager.operate_blockwise(self, other, array_op)
#    1466 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1467     """
#    1468     Apply array_op blockwise with another (aligned) BlockManager.
#    1469     """
# -> 1470     return operate_blockwise(self, other, array_op)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/internals/ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
X = df1.drop(columns=['Profit'])
y = df1['Profit']

# %%
x_train,x_test,y_train,y_test= train_test_split(X,y, test_size=0.3)

# %%
def prep_model(hidden_dim):
    model = Sequential()
    for i in range(1,len(hidden_dim)-1):
        if (i==1):
            model.add(Dense(hidden_dim[i],input_dim=hidden_dim[0],kernel_initializer="normal",activation="relu"))
        else:
            model.add(Dense(hidden_dim[i],activation="relu"))
    model.add(Dense(hidden_dim[-1]))
    model.compile(loss="mean_squared_error",optimizer="adam",metrics = ["accuracy"])
    return (model)

# %%
model = prep_model([6,50,1])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(np.array(x_train),np.array(y_train),epochs=900)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 model.fit(np.array(x_train),np.array(y_train),epochs=900)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).

# %%
train = model.predict(np.array(x_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 train = model.predict(np.array(x_train))
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).

# %%
train = pd.Series([i[0] for i in train])

# %%
np.sqrt(np.mean((train-y_train)**2))
# Out:
# 0.25364808552652784

# %%
np.corrcoef(train,y_train)
# Out:
# array([[1.        , 0.98764664],
#        [0.98764664, 1.        ]])

# %% [markdown]
# ## __4 - Conclusion__

# %%
plt.plot(train,y_train,"bo")
